# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install grakel
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.8 MB/s eta 0:00:00
# ...

# %%
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.0 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/ALTEGRAD_lab_4_MLForGraphs_2024/code/')

# %%
# !python '/content/drive/MyDrive/ALTEGRAD_lab_4_MLForGraphs_2024/code/part1/code_lab_exploration.py'
# Out:
# Number of nodes: 9877
# Number of edges: 25998
# Number of connected components :  429
# Number of nodes of largest cc: 8638
# Number of edges of largest cc: 24827
# fraction of nodes :  0.8745570517363572
# fraction of edges :  0.9549580736979768

# %%
# !python '/content/drive/MyDrive/ALTEGRAD_lab_4_MLForGraphs_2024/code/part2/code_lab_community_detection.py'
# Out:
# {'24325': 0, '24394': 0, '40517': 0, '58507': 0, '3737': 0, '3905': 0, '7237': 0, '12715': 0, '13648': 0, '13659': 0, '13664': 0, '14304': 0, '14823': 0, '17370': 0, '18956': 0, '19615': 0, '19660': 0, '21669': 0, '23106': 0, '24832': 0, '26021': 0, '26363': 0, '28240': 0, '35376': 0, '35424': 0, '36383': 0, '36860': 0, '37616': 0, '37932': 0, '39984': 0, '41687': 0, '44934': 0, '48192': 0, '51464': 0, '55079': 0, '59077': 0, '59471': 0, '59870': 0, '61742': 0, '61796': 0, '62227': 0, '65346': 0, '66689': 0, '67851': 0, '24897': 0, '30545': 0, '42653': 0, '1182': 0, '3175': 0, '5379': 0, '33426': 0, '34071': 0, '36192': 0, '39688': 0, '63113': 0, '65086': 0, '66829': 0, '68041': 0, '554': 0, '3088': 0, '4503': 0, '4521': 0, '6142': 0, '9117': 0, '11180': 0, '12981': 0, '13769': 0, '20394': 0, '21477': 0, '22916': 0, '24295': 0, '28268': 0, '33726': 0, '40894': 0, '44594': 0, '45385': 0, '46139': 0, '49541': 0, '50970': 0, '53159': 0, '55835': 0, '56948': 0, '57628': 0, '60251': 0, '6
# ...

# %%
# !python '/content/drive/MyDrive/ALTEGRAD_lab_4_MLForGraphs_2024/code/part3/code_lab_graph_classification.py'
# Out:
# Accuracy Shortest Path Kernel: 0.8947368421052632
# Accuracy Graphlet Kernel: 0.8421052631578947

# %%
# !python '/content/drive/MyDrive/ALTEGRAD_lab_4_MLForGraphs_2024/code/part3/grakel_script.py'
# Out:
# Vocabulary size:  7151
# Example of graph-of-words representation of document
# Figure(640x480)
# Accuracy WL subtree Kernel : 0.944
# Accuracy Neighborhood Hash Kernel: 0.556
